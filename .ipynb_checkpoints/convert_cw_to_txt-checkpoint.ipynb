# %%
import chipwhisperer as cw
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
def save_files(folder, array, input_file, input_array):
    isExist = os.path.exists(folder)
    if not isExist:
        os.makedirs(folder)
    no_of_traces = len(input_array)
    for n in range(no_of_traces):
        with open(folder + "/trace_"+str(n)+".txt","w+") as file:
            for record in array[n]:
                file.write(str(record)+"\n")
        file.close()
        if (n + 1) % 100 == 0:
            print(f'converted {(n + 1)} traces')
    
    with open(folder + "/" + input_file,"w+") as file:
        for i in range(no_of_traces):
            file.write(str(input_array[i])+"\n")
        file.close()
    return

# %%
project_folder = "./cw_projects/"
#project_name = "protected100k-2"
project_name = "project-protected-10k-decimate1_new_weights"

# %%
proj = cw.open_project(project_folder + project_name)

# %%
trace_waves_arr = []
inputs_arr = []
counter = 0
for trace in proj.traces:
    trace_waves_arr.append(trace.wave)
    inputs_arr.append(trace.textin)
    counter += 1
    if counter == 10:
        break

trace_waves_arr = np.array(trace_waves_arr)
print(len(trace_waves_arr))
print(len(inputs_arr))
print(len(trace_waves_arr[0]))
# Out:
# 10
# 10
# 24430

# %%
# Added this to verify what the trace looks like
def plot_trace(trace, vlines=[], save=False, fig_name='figure.svg'):
    # Plot the trace
    plt.plot(trace, linewidth=0.8)
    if len(vlines) > 0:
        plt.vlines(vlines, -0.3, 0.2, colors='red')
    if save:
        plt.savefig(fig_name, format='svg')
    plt.show()
    
plot_trace(trace_waves_arr[0])

# %%
plot_trace(trace_waves_arr[0])

# %%
save_files("txt_traces/" + project_name, trace_waves_arr, "inputs.txt", inputs_arr)
# Out:
# converted 100 traces
# converted 200 traces
# converted 300 traces
# converted 400 traces
# converted 500 traces
# converted 600 traces
# converted 700 traces
# converted 800 traces
# converted 900 traces
# converted 1000 traces
# converted 1100 traces
# converted 1200 traces
# converted 1300 traces
# converted 1400 traces
# converted 1500 traces
# converted 1600 traces
# converted 1700 traces
# converted 1800 traces
# converted 1900 traces
# converted 2000 traces
# converted 2100 traces
# converted 2200 traces
# converted 2300 traces
# converted 2400 traces
# converted 2500 traces
# converted 2600 traces
# converted 2700 traces
# converted 2800 traces
# converted 2900 traces
# converted 3000 traces
# converted 3100 traces
# converted 3200 traces
# converted 3300 traces
# converted 3400 traces
# converted 3500 traces
# converted 3600 traces
# converted 3700 traces
# converted 3800 traces
# converted 3900 traces
# converted 4000 traces
# converted 4100 traces
# converted 4200 traces
# converted 4300 traces
# converted 4400 traces
# converted 4500 traces
# converted 4600 traces
# converted 4700 traces
# converted 4800 traces
# converted 4900 traces
# converted 5000 traces
# converted 5100 traces
# converted 5200 traces
# converted 5300 traces
# converted 5400 traces
# converted 5500 traces
# converted 5600 traces
# converted 5700 traces
# converted 5800 traces
# converted 5900 traces
# converted 6000 traces
# converted 6100 traces
# converted 6200 traces
# converted 6300 traces
# converted 6400 traces
# converted 6500 traces
# converted 6600 traces
# converted 6700 traces
# converted 6800 traces
# converted 6900 traces
# converted 7000 traces
# converted 7100 traces
# converted 7200 traces
# converted 7300 traces
# converted 7400 traces
# converted 7500 traces
# converted 7600 traces
# converted 7700 traces
# converted 7800 traces
# converted 7900 traces
# converted 8000 traces
# converted 8100 traces
# converted 8200 traces
# converted 8300 traces
# converted 8400 traces
# converted 8500 traces
# converted 8600 traces
# converted 8700 traces
# converted 8800 traces
# converted 8900 traces
# converted 9000 traces
# converted 9100 traces
# converted 9200 traces
# converted 9300 traces
# converted 9400 traces
# converted 9500 traces
# converted 9600 traces
# converted 9700 traces
# converted 9800 traces
# converted 9900 traces
# converted 10000 traces
# converted 10100 traces
# converted 10200 traces
# converted 10300 traces
# converted 10400 traces
# converted 10500 traces
# converted 10600 traces
# converted 10700 traces
# converted 10800 traces
# converted 10900 traces
# converted 11000 traces
# converted 11100 traces
# converted 11200 traces
# converted 11300 traces
# converted 11400 traces
# converted 11500 traces
# converted 11600 traces
# converted 11700 traces
# converted 11800 traces
# converted 11900 traces
# converted 12000 traces
# converted 12100 traces
# converted 12200 traces
# converted 12300 traces
# converted 12400 traces
# converted 12500 traces
# converted 12600 traces
# converted 12700 traces
# converted 12800 traces
# converted 12900 traces
# converted 13000 traces
# converted 13100 traces
# converted 13200 traces
# converted 13300 traces
# converted 13400 traces
# converted 13500 traces
# converted 13600 traces
# converted 13700 traces
# converted 13800 traces
# converted 13900 traces
# converted 14000 traces
# converted 14100 traces
# converted 14200 traces
# converted 14300 traces
# converted 14400 traces
# converted 14500 traces
# converted 14600 traces
# converted 14700 traces
# converted 14800 traces
# converted 14900 traces
# converted 15000 traces
# converted 15100 traces
# converted 15200 traces
# converted 15300 traces
# converted 15400 traces
# converted 15500 traces
# converted 15600 traces
# converted 15700 traces
# converted 15800 traces
# converted 15900 traces
# converted 16000 traces
# converted 16100 traces
# converted 16200 traces
# converted 16300 traces
# converted 16400 traces
# converted 16500 traces
# converted 16600 traces
# converted 16700 traces
# converted 16800 traces
# converted 16900 traces
# converted 17000 traces
# converted 17100 traces
# converted 17200 traces
# converted 17300 traces
# converted 17400 traces
# converted 17500 traces
# converted 17600 traces
# converted 17700 traces
# converted 17800 traces
# converted 17900 traces
# converted 18000 traces
# converted 18100 traces
# converted 18200 traces
# converted 18300 traces
# converted 18400 traces
# converted 18500 traces
# converted 18600 traces
# converted 18700 traces
# converted 18800 traces
# converted 18900 traces
# converted 19000 traces
# converted 19100 traces
# converted 19200 traces
# converted 19300 traces
# converted 19400 traces
# converted 19500 traces
# converted 19600 traces
# converted 19700 traces
# converted 19800 traces
# converted 19900 traces
# converted 20000 traces
# converted 20100 traces
# converted 20200 traces
# converted 20300 traces
# converted 20400 traces
# converted 20500 traces
# converted 20600 traces
# converted 20700 traces
# converted 20800 traces
# converted 20900 traces
# converted 21000 traces
# converted 21100 traces
# converted 21200 traces
# converted 21300 traces
# converted 21400 traces
# converted 21500 traces
# converted 21600 traces
# converted 21700 traces
# converted 21800 traces
# converted 21900 traces
# converted 22000 traces
# converted 22100 traces
# converted 22200 traces
# converted 22300 traces
# converted 22400 traces
# converted 22500 traces
# converted 22600 traces
# converted 22700 traces
# converted 22800 traces
# converted 22900 traces
# converted 23000 traces
# converted 23100 traces
# converted 23200 traces
# converted 23300 traces
# converted 23400 traces
# converted 23500 traces
# converted 23600 traces
# converted 23700 traces
# converted 23800 traces
# converted 23900 traces
# converted 24000 traces
# converted 24100 traces
# converted 24200 traces
# converted 24300 traces
# converted 24400 traces
# converted 24500 traces
# converted 24600 traces
# converted 24700 traces
# converted 24800 traces
# converted 24900 traces
# converted 25000 traces
# converted 25100 traces
# converted 25200 traces
# converted 25300 traces
# converted 25400 traces
# converted 25500 traces
# converted 25600 traces
# converted 25700 traces
# converted 25800 traces
# converted 25900 traces
# converted 26000 traces
# converted 26100 traces
# converted 26200 traces
# converted 26300 traces
# converted 26400 traces
# converted 26500 traces
# converted 26600 traces
# converted 26700 traces
# converted 26800 traces
# converted 26900 traces
# converted 27000 traces
# converted 27100 traces
# converted 27200 traces
# converted 27300 traces
# converted 27400 traces
# converted 27500 traces
# converted 27600 traces
# converted 27700 traces
# converted 27800 traces
# converted 27900 traces
# converted 28000 traces
# converted 28100 traces
# converted 28200 traces
# converted 28300 traces
# converted 28400 traces
# converted 28500 traces
# converted 28600 traces
# converted 28700 traces
# converted 28800 traces
# converted 28900 traces
# converted 29000 traces
# converted 29100 traces
# converted 29200 traces
# converted 29300 traces
# converted 29400 traces
# converted 29500 traces
# converted 29600 traces
# converted 29700 traces
# converted 29800 traces
# converted 29900 traces
# converted 30000 traces
# converted 30100 traces
# converted 30200 traces
# converted 30300 traces
# converted 30400 traces
# converted 30500 traces
# converted 30600 traces
# converted 30700 traces
# converted 30800 traces
# converted 30900 traces
# converted 31000 traces
# converted 31100 traces
# converted 31200 traces
# converted 31300 traces
# converted 31400 traces
# converted 31500 traces
# converted 31600 traces
# converted 31700 traces
# converted 31800 traces
# converted 31900 traces
# converted 32000 traces
# converted 32100 traces
# converted 32200 traces
# converted 32300 traces
# converted 32400 traces
# converted 32500 traces
# converted 32600 traces
# converted 32700 traces
# converted 32800 traces
# converted 32900 traces
# converted 33000 traces
# converted 33100 traces
# converted 33200 traces
# converted 33300 traces
# converted 33400 traces
# converted 33500 traces
# converted 33600 traces
# converted 33700 traces
# converted 33800 traces
# converted 33900 traces
# converted 34000 traces
# converted 34100 traces
# converted 34200 traces
# converted 34300 traces
# converted 34400 traces
# converted 34500 traces
# converted 34600 traces
# converted 34700 traces
# converted 34800 traces
# converted 34900 traces
# converted 35000 traces
# converted 35100 traces
# converted 35200 traces
# converted 35300 traces
# converted 35400 traces
# converted 35500 traces
# converted 35600 traces
# converted 35700 traces
# converted 35800 traces
# converted 35900 traces
# converted 36000 traces
# converted 36100 traces
# converted 36200 traces
# converted 36300 traces
# converted 36400 traces
# converted 36500 traces
# converted 36600 traces
# converted 36700 traces
# converted 36800 traces
# converted 36900 traces
# converted 37000 traces
# converted 37100 traces
# converted 37200 traces
# converted 37300 traces
# converted 37400 traces
# converted 37500 traces
# converted 37600 traces
# converted 37700 traces
# converted 37800 traces
# converted 37900 traces
# converted 38000 traces
# converted 38100 traces
# converted 38200 traces
# converted 38300 traces
# converted 38400 traces
# converted 38500 traces
# converted 38600 traces
# converted 38700 traces
# converted 38800 traces
# converted 38900 traces
# converted 39000 traces
# converted 39100 traces
# converted 39200 traces
# converted 39300 traces
# converted 39400 traces
# converted 39500 traces
# converted 39600 traces
# converted 39700 traces
# converted 39800 traces
# converted 39900 traces
# converted 40000 traces
# converted 40100 traces
# converted 40200 traces
# converted 40300 traces
# converted 40400 traces
# converted 40500 traces
# converted 40600 traces
# converted 40700 traces
# converted 40800 traces
# converted 40900 traces
# converted 41000 traces
# converted 41100 traces
# converted 41200 traces
# converted 41300 traces
# converted 41400 traces
# converted 41500 traces
# converted 41600 traces
# converted 41700 traces
# converted 41800 traces
# converted 41900 traces
# converted 42000 traces
# converted 42100 traces
# converted 42200 traces
# converted 42300 traces
# converted 42400 traces
# converted 42500 traces
# converted 42600 traces
# converted 42700 traces
# converted 42800 traces
# converted 42900 traces
# converted 43000 traces
# converted 43100 traces
# converted 43200 traces
# converted 43300 traces
# converted 43400 traces
# converted 43500 traces
# converted 43600 traces
# converted 43700 traces
# converted 43800 traces
# converted 43900 traces
# converted 44000 traces
# converted 44100 traces
# converted 44200 traces
# converted 44300 traces
# converted 44400 traces
# converted 44500 traces
# converted 44600 traces
# converted 44700 traces
# converted 44800 traces
# converted 44900 traces
# converted 45000 traces
# converted 45100 traces
# converted 45200 traces
# converted 45300 traces
# converted 45400 traces
# converted 45500 traces
# converted 45600 traces
# converted 45700 traces
# converted 45800 traces
# converted 45900 traces
# converted 46000 traces
# converted 46100 traces
# converted 46200 traces
# converted 46300 traces
# converted 46400 traces
# converted 46500 traces
# converted 46600 traces
# converted 46700 traces
# converted 46800 traces
# converted 46900 traces
# converted 47000 traces
# converted 47100 traces
# converted 47200 traces
# converted 47300 traces
# converted 47400 traces
# converted 47500 traces
# converted 47600 traces
# converted 47700 traces
# converted 47800 traces
# converted 47900 traces
# converted 48000 traces
# converted 48100 traces
# converted 48200 traces
# converted 48300 traces
# converted 48400 traces
# converted 48500 traces
# converted 48600 traces
# converted 48700 traces
# converted 48800 traces
# converted 48900 traces
# converted 49000 traces
# converted 49100 traces
# converted 49200 traces
# converted 49300 traces
# converted 49400 traces
# converted 49500 traces
# converted 49600 traces
# converted 49700 traces
# converted 49800 traces
# converted 49900 traces
# converted 50000 traces
# converted 50100 traces
# converted 50200 traces
# converted 50300 traces
# converted 50400 traces
# converted 50500 traces
# converted 50600 traces
# converted 50700 traces
# converted 50800 traces
# converted 50900 traces
# converted 51000 traces
# converted 51100 traces
# converted 51200 traces
# converted 51300 traces
# converted 51400 traces
# converted 51500 traces
# converted 51600 traces
# converted 51700 traces
# converted 51800 traces
# converted 51900 traces
# converted 52000 traces
# converted 52100 traces
# converted 52200 traces
# converted 52300 traces
# converted 52400 traces
# converted 52500 traces
# converted 52600 traces
# converted 52700 traces
# converted 52800 traces
# converted 52900 traces
# converted 53000 traces
# converted 53100 traces
# converted 53200 traces
# converted 53300 traces
# converted 53400 traces
# converted 53500 traces
# converted 53600 traces
# converted 53700 traces
# converted 53800 traces
# converted 53900 traces
# converted 54000 traces
# converted 54100 traces
# converted 54200 traces
# converted 54300 traces
# converted 54400 traces
# converted 54500 traces
# converted 54600 traces
# converted 54700 traces
# converted 54800 traces
# converted 54900 traces
# converted 55000 traces
# converted 55100 traces
# converted 55200 traces
# converted 55300 traces
# converted 55400 traces
# converted 55500 traces
# converted 55600 traces
# converted 55700 traces
# converted 55800 traces
# converted 55900 traces
# converted 56000 traces
# converted 56100 traces
# converted 56200 traces
# converted 56300 traces
# converted 56400 traces
# converted 56500 traces
# converted 56600 traces
# converted 56700 traces
# converted 56800 traces
# converted 56900 traces
# converted 57000 traces
# converted 57100 traces
# converted 57200 traces
# converted 57300 traces
# converted 57400 traces
# converted 57500 traces
# converted 57600 traces
# converted 57700 traces
# converted 57800 traces
# converted 57900 traces
# converted 58000 traces
# converted 58100 traces
# converted 58200 traces
# converted 58300 traces
# converted 58400 traces
# converted 58500 traces
# converted 58600 traces
# converted 58700 traces
# converted 58800 traces
# converted 58900 traces
# converted 59000 traces
# converted 59100 traces
# converted 59200 traces
# converted 59300 traces
# converted 59400 traces
# converted 59500 traces
# converted 59600 traces
# converted 59700 traces
# converted 59800 traces
# converted 59900 traces
# converted 60000 traces
# converted 60100 traces
# converted 60200 traces
# converted 60300 traces
# converted 60400 traces
# converted 60500 traces
# converted 60600 traces
# converted 60700 traces
# converted 60800 traces
# converted 60900 traces
# converted 61000 traces
# converted 61100 traces
# converted 61200 traces
# converted 61300 traces
# converted 61400 traces
# converted 61500 traces
# converted 61600 traces
# converted 61700 traces
# converted 61800 traces
# converted 61900 traces
# converted 62000 traces
# converted 62100 traces
# converted 62200 traces
# converted 62300 traces
# converted 62400 traces
# converted 62500 traces
# converted 62600 traces
# converted 62700 traces
# converted 62800 traces
# converted 62900 traces
# converted 63000 traces
# converted 63100 traces
# converted 63200 traces
# converted 63300 traces
# converted 63400 traces
# converted 63500 traces
# converted 63600 traces
# converted 63700 traces
# converted 63800 traces
# converted 63900 traces
# converted 64000 traces
# converted 64100 traces
# converted 64200 traces
# converted 64300 traces
# converted 64400 traces
# converted 64500 traces
# converted 64600 traces
# converted 64700 traces
# converted 64800 traces
# converted 64900 traces
# converted 65000 traces
# converted 65100 traces
# converted 65200 traces
# converted 65300 traces
# converted 65400 traces
# converted 65500 traces
# converted 65600 traces
# converted 65700 traces
# converted 65800 traces
# converted 65900 traces
# converted 66000 traces
# converted 66100 traces
# converted 66200 traces
# converted 66300 traces
# converted 66400 traces
# converted 66500 traces
# converted 66600 traces
# converted 66700 traces
# converted 66800 traces
# converted 66900 traces
# converted 67000 traces
# converted 67100 traces
# converted 67200 traces
# converted 67300 traces
# converted 67400 traces
# converted 67500 traces
# converted 67600 traces
# converted 67700 traces
# converted 67800 traces
# converted 67900 traces
# converted 68000 traces
# converted 68100 traces
# converted 68200 traces
# converted 68300 traces
# converted 68400 traces
# converted 68500 traces
# converted 68600 traces
# converted 68700 traces
# converted 68800 traces
# converted 68900 traces
# converted 69000 traces
# converted 69100 traces
# converted 69200 traces
# converted 69300 traces
# converted 69400 traces
# converted 69500 traces
# converted 69600 traces
# converted 69700 traces
# converted 69800 traces
# converted 69900 traces
# converted 70000 traces
# converted 70100 traces
# converted 70200 traces
# converted 70300 traces
# converted 70400 traces
# converted 70500 traces
# converted 70600 traces
# converted 70700 traces
# converted 70800 traces
# converted 70900 traces
# converted 71000 traces
# converted 71100 traces
# converted 71200 traces
# converted 71300 traces
# converted 71400 traces
# converted 71500 traces
# converted 71600 traces
# converted 71700 traces
# converted 71800 traces
# converted 71900 traces
# converted 72000 traces
# converted 72100 traces
# converted 72200 traces
# converted 72300 traces
# converted 72400 traces
# converted 72500 traces
# converted 72600 traces
# converted 72700 traces
# converted 72800 traces
# converted 72900 traces
# converted 73000 traces
# converted 73100 traces
# converted 73200 traces
# converted 73300 traces
# converted 73400 traces
# converted 73500 traces
# converted 73600 traces
# converted 73700 traces
# converted 73800 traces
# converted 73900 traces
# converted 74000 traces
# converted 74100 traces
# converted 74200 traces
# converted 74300 traces
# converted 74400 traces
# converted 74500 traces
# converted 74600 traces
# converted 74700 traces
# converted 74800 traces
# converted 74900 traces
# converted 75000 traces
# converted 75100 traces
# converted 75200 traces
# converted 75300 traces
# converted 75400 traces
# converted 75500 traces
# converted 75600 traces
# converted 75700 traces
# converted 75800 traces
# converted 75900 traces
# converted 76000 traces
# converted 76100 traces
# converted 76200 traces
# converted 76300 traces
# converted 76400 traces
# converted 76500 traces
# converted 76600 traces
# converted 76700 traces
# converted 76800 traces
# converted 76900 traces
# converted 77000 traces
# converted 77100 traces
# converted 77200 traces
# converted 77300 traces
# converted 77400 traces
# converted 77500 traces
# converted 77600 traces
# converted 77700 traces
# converted 77800 traces
# converted 77900 traces
# converted 78000 traces
# converted 78100 traces
# converted 78200 traces
# converted 78300 traces
# converted 78400 traces
# converted 78500 traces
# converted 78600 traces
# converted 78700 traces
# converted 78800 traces
# converted 78900 traces
# converted 79000 traces
# converted 79100 traces
# converted 79200 traces
# converted 79300 traces
# converted 79400 traces
# converted 79500 traces
# converted 79600 traces
# converted 79700 traces
# converted 79800 traces
# converted 79900 traces
# converted 80000 traces
# converted 80100 traces
# converted 80200 traces
# converted 80300 traces
# converted 80400 traces
# converted 80500 traces
# converted 80600 traces
# converted 80700 traces
# converted 80800 traces
# converted 80900 traces
# converted 81000 traces
# converted 81100 traces
# converted 81200 traces
# converted 81300 traces
# converted 81400 traces
# converted 81500 traces
# converted 81600 traces
# converted 81700 traces
# converted 81800 traces
# converted 81900 traces
# converted 82000 traces
# converted 82100 traces
# converted 82200 traces
# converted 82300 traces
# converted 82400 traces
# converted 82500 traces
# converted 82600 traces
# converted 82700 traces
# converted 82800 traces
# converted 82900 traces
# converted 83000 traces
# converted 83100 traces
# converted 83200 traces
# converted 83300 traces
# converted 83400 traces
# converted 83500 traces
# converted 83600 traces
# converted 83700 traces
# converted 83800 traces
# converted 83900 traces
# converted 84000 traces
# converted 84100 traces
# converted 84200 traces
# converted 84300 traces
# converted 84400 traces
# converted 84500 traces
# converted 84600 traces
# converted 84700 traces
# converted 84800 traces
# converted 84900 traces
# converted 85000 traces
# converted 85100 traces
# converted 85200 traces
# converted 85300 traces
# converted 85400 traces
# converted 85500 traces
# converted 85600 traces
# converted 85700 traces
# converted 85800 traces
# converted 85900 traces
# converted 86000 traces
# converted 86100 traces
# converted 86200 traces
# converted 86300 traces
# converted 86400 traces
# converted 86500 traces
# converted 86600 traces
# converted 86700 traces
# converted 86800 traces
# converted 86900 traces
# converted 87000 traces
# converted 87100 traces
# converted 87200 traces
# converted 87300 traces
# converted 87400 traces
# converted 87500 traces
# converted 87600 traces
# converted 87700 traces
# converted 87800 traces
# converted 87900 traces
# converted 88000 traces
# converted 88100 traces
# converted 88200 traces
# converted 88300 traces
# converted 88400 traces
# converted 88500 traces
# converted 88600 traces
# converted 88700 traces
# converted 88800 traces
# converted 88900 traces
# converted 89000 traces
# converted 89100 traces
# converted 89200 traces
# converted 89300 traces
# converted 89400 traces
# converted 89500 traces
# converted 89600 traces
# converted 89700 traces
# converted 89800 traces
# converted 89900 traces
# converted 90000 traces
# converted 90100 traces
# converted 90200 traces
# converted 90300 traces
# converted 90400 traces
# converted 90500 traces
# converted 90600 traces
# converted 90700 traces
# converted 90800 traces
# converted 90900 traces
# converted 91000 traces
# converted 91100 traces
# converted 91200 traces
# converted 91300 traces
# converted 91400 traces
# converted 91500 traces
# converted 91600 traces
# converted 91700 traces
# converted 91800 traces
# converted 91900 traces
# converted 92000 traces
# converted 92100 traces
# converted 92200 traces
# converted 92300 traces
# converted 92400 traces
# converted 92500 traces
# converted 92600 traces
# converted 92700 traces
# converted 92800 traces
# converted 92900 traces
# converted 93000 traces
# converted 93100 traces
# converted 93200 traces
# converted 93300 traces
# converted 93400 traces
# converted 93500 traces
# converted 93600 traces
# converted 93700 traces
# converted 93800 traces
# converted 93900 traces
# converted 94000 traces
# converted 94100 traces
# converted 94200 traces
# converted 94300 traces
# converted 94400 traces
# converted 94500 traces
# converted 94600 traces
# converted 94700 traces
# converted 94800 traces
# converted 94900 traces
# converted 95000 traces
# converted 95100 traces
# converted 95200 traces
# converted 95300 traces
# converted 95400 traces
# converted 95500 traces
# converted 95600 traces
# converted 95700 traces
# converted 95800 traces
# converted 95900 traces
# converted 96000 traces
# converted 96100 traces
# converted 96200 traces
# converted 96300 traces
# converted 96400 traces
# converted 96500 traces
# converted 96600 traces
# converted 96700 traces
# converted 96800 traces
# converted 96900 traces
# converted 97000 traces
# converted 97100 traces
# converted 97200 traces
# converted 97300 traces
# converted 97400 traces
# converted 97500 traces
# converted 97600 traces
# converted 97700 traces
# converted 97800 traces
# converted 97900 traces
# converted 98000 traces
# converted 98100 traces
# converted 98200 traces
# converted 98300 traces
# converted 98400 traces
# converted 98500 traces
# converted 98600 traces
# converted 98700 traces
# converted 98800 traces
# converted 98900 traces
# converted 99000 traces
# converted 99100 traces
# converted 99200 traces
# converted 99300 traces
# converted 99400 traces
# converted 99500 traces
# converted 99600 traces
# converted 99700 traces
# converted 99800 traces
# converted 99900 traces
# converted 100000 traces
